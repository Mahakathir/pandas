# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.0.3-cp39-cp39-win_amd64.whl (10.8 MB)
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#      -------------------------------------- 341.8/341.8 kB 5.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -cipy (c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages)

# %%
import pandas as p
import numpy as n

# %%
a1=p.Series(["psd","prag","pmist"],index=[1,2,3])

# %%
print(a1)
# Out:
# 1      psd
# 2     prag
# 3    pmist
# dtype: object

# %%
season={"name":{1:"kathir",2:"joshua",3:"vasanth",4:"althaf"},
       "age":{1:"19",2:"19",3:"20",4:"20"},"Blood Group":{1:"o+",2:"o+",3:"o+",4:"o+"}}

# %%
a=p.DataFrame(season,columns=["name","age","Blood Group"])

# %%
a
# Out:
#       name age Blood Group
# 1   kathir  19          o+
# 2   joshua  19          o+
# 3  vasanth  20          o+
# 4   althaf  20          o+

# %%
b=p.DataFrame(n.random.randint(0,300,size=(20,4)),columns=list('abcd'))

# %%
print(b)
# Out:
#       a    b    c    d
# 0    83  144  270  275
# 1   299  161  200  179
# 2   107   71   72   30
# 3     9   17   22   67
# 4   138   30  276  179
# 5   224  224  254  101
# 6    76   84   17  272
# 7    99    5  255   34
# 8    63   77   12  289
# 9   142   90  295   62
# 10  154  201  149  211
# 11  123  113  256  214
# 12   79  263  218   44
# 13   92  234  248  191
# 14  202  192  162   20
# 15  196   48  263   84
# 16  145    1  109  135
# 17  274  193   53  246
# 18  242  276  157  177
# 19   11  130  127  207

# %%
b.to_csv("C:/TURBOC3/BIN/ipt/pandas/panda.csv")

# %%
d=p.read_csv("C:/TURBOC3/BIN/ipt/pandas/panda.csv")

# %%
d
# Out:
#     Unnamed: 0    a    b    c    d
# 0            0   83  144  270  275
# 1            1  299  161  200  179
# 2            2  107   71   72   30
# 3            3    9   17   22   67
# 4            4  138   30  276  179
# 5            5  224  224  254  101
# 6            6   76   84   17  272
# 7            7   99    5  255   34
# 8            8   63   77   12  289
# 9            9  142   90  295   62
# 10          10  154  201  149  211
# 11          11  123  113  256  214
# 12          12   79  263  218   44
# 13          13   92  234  248  191
# 14          14  202  192  162   20
# 15          15  196   48  263   84
# 16          16  145    1  109  135
# 17          17  274  193   53  246
# 18          18  242  276  157  177
# 19          19   11  130  127  207

# %%
d.drop("Unnamed: 0",axis=1)
# Out:
#       a    b    c    d
# 0    83  144  270  275
# 1   299  161  200  179
# 2   107   71   72   30
# 3     9   17   22   67
# 4   138   30  276  179
# 5   224  224  254  101
# 6    76   84   17  272
# 7    99    5  255   34
# 8    63   77   12  289
# 9   142   90  295   62
# 10  154  201  149  211
# 11  123  113  256  214
# 12   79  263  218   44
# 13   92  234  248  191
# 14  202  192  162   20
# 15  196   48  263   84
# 16  145    1  109  135
# 17  274  193   53  246
# 18  242  276  157  177
# 19   11  130  127  207

# %%
d.drop("b",axis=1)
# Out:
#     Unnamed: 0    a    c    d
# 0            0   83  270  275
# 1            1  299  200  179
# 2            2  107   72   30
# 3            3    9   22   67
# 4            4  138  276  179
# 5            5  224  254  101
# 6            6   76   17  272
# 7            7   99  255   34
# 8            8   63   12  289
# 9            9  142  295   62
# 10          10  154  149  211
# 11          11  123  256  214
# 12          12   79  218   44
# 13          13   92  248  191
# 14          14  202  162   20
# 15          15  196  263   84
# 16          16  145  109  135
# 17          17  274   53  246
# 18          18  242  157  177
# 19          19   11  127  207

# %%
d.drop(0,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 d.drop(0,axis=1)
#
# File ~\anaconda3\envs\mahakathit\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...
